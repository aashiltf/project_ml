# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
stores_train = pd.read_csv('data/stores_train.csv')
stores_test = pd.read_csv('data/stores_test.csv')

grunnkrets_households_num_persons = pd.read_csv('data/grunnkrets_households_num_persons.csv')

# %%
stores_with_households_num_persons = stores_train.merge(grunnkrets_households_num_persons, how="left", on="grunnkrets_id")

# %%
grunnkrets_households_num_persons.head().T
#stores_with_households_num_persons.head().T
# Out:
#                                              0         1         2         3  \
# grunnkrets_id                         12010509  14390206  18040514  18040804
# year                                      2015      2015      2015      2015
# couple_children_0_to_5_years                 0         0        10         0
# couple_children_18_or_above                  0         7         0         0
# couple_children_6_to_17_years                4         0         0         0
# couple_without_children                      0         0         0         0
# single_parent_children_0_to_5_years          0         0         0         0
# single_parent_children_18_or_above           0         0         0         0
# single_parent_children_6_to_17_years         0         0         0         0
# singles                                      4         3         7         0
#
#                                              4
# grunnkrets_id                         18200101
# ...

# %%
stores_train.head().T
# Out:
#                                                        0  \
# store_id                       983540538-974187930-44774
# year                                                2016
# store_name           MCDONALD'S BRAGERNES TORG MAGASINET
# plaace_hierarchy_id                              1.1.1.0
# sales_channel_name                 Hamburger restaurants
# grunnkrets_id                                    6020303
# address                                BRAGERNES TORG 13
# lat                                            59.743104
# lon                                            10.204928
# chain_name                                     MCDONALDS
# mall_name                              Magasinet Drammen
# revenue                                           17.998
#
#                                               1                          2  \
# store_id              987074191-973117734-44755  984890265-981157303-64491
# ...

# %%
stores_with_households_num_persons.head().T
# Out:
#                                                                         0  \
# store_id                                        983540538-974187930-44774
# year_x                                                               2016
# store_name                            MCDONALD'S BRAGERNES TORG MAGASINET
# plaace_hierarchy_id                                               1.1.1.0
# sales_channel_name                                  Hamburger restaurants
# grunnkrets_id                                                     6020303
# address                                                 BRAGERNES TORG 13
# lat                                                             59.743104
# lon                                                             10.204928
# chain_name                                                      MCDONALDS
# mall_name                                               Magasinet Drammen
# revenue                                                            17.998
# ...
