# %% [markdown]
# # Hypothesis
#
# Areas with larger revenue will have households living there with higher average income
#
# Grunnkrets-områder med høy inntekts-gjennomsnitt, vil gjøre at samme grunnkrets-område har høyere revenue på butikker
#
# - grunnkrets_id referer til et område
# - hvis man merger grunnkrets_id i income og stores_train
# - merge filer
# - merge de med samme grunnkrets id

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
stores_train = pd.read_csv('../data/stores_train.csv')
stores_test = pd.read_csv('../data/stores_test.csv')
grunnkrets_income_households = pd.read_csv('../data/grunnkrets_income_households.csv')

# %%
print(grunnkrets_income_households.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26530 entries, 0 to 26529
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   grunnkrets_id                26530 non-null  int64
#  1   year                         26530 non-null  int64
#  2   all_households               26530 non-null  int64
#  3   singles                      26530 non-null  int64
#  4   couple_without_children      26530 non-null  int64
#  5   couple_with_children         26530 non-null  int64
#  6   other_households             26530 non-null  int64
#  7   single_parent_with_children  26530 non-null  int64
# dtypes: int64(8)
# memory usage: 1.6 MB
# None

# %%
#grunnkrets_income_households.year.drop("2016")
#print(grunnkrets_income_households.year)

grunnkrets_income_households = grunnkrets_income_households[grunnkrets_income_households.year != 2015]

grunnkrets_income_households.head()

#grunnkrets_income_households.drop(labels=["year"], axis=0, ("2016")
# Out:
#     grunnkrets_id  year  all_households  singles  couple_without_children  \
# 0        14200105  2016          551700   270300                        0
# 3        14200401  2016          507000   250700                        0
# 11       14200402  2016          507000   250700                        0
# 12       14200101  2016          551700   270300                        0
# 13       14200103  2016          551700   270300                        0
#
#     couple_with_children  other_households  single_parent_with_children
# 0                      0                 0                            0
# 3                      0                 0                            0
# 11                     0                 0                            0
# 12                     0                 0                            0
# 13                     0                 0                            0

# %%
# Merging

stores_with_households_income = stores_train.merge(grunnkrets_income_households, on="grunnkrets_id", how="left")

# %%
# merged file has 25 684
stores_with_households_income.shape[0]
# Out:
# 12859

# %%
stores_with_households_income.head()
# Out:
#                      store_id  year_x                           store_name  \
# 0   983540538-974187930-44774    2016  MCDONALD'S BRAGERNES TORG MAGASINET
# 1   987074191-973117734-44755    2016           MCDONALD'S KLINGENBERGGATA
# 2   984890265-981157303-64491    2016                 BURGER KING HØNEFOSS
# 3  914057442-992924179-126912    2016        BURGER KING GLASSHUSPASSASJEN
# 4  913018583-913063538-668469    2016             BURGER KING TILLERTORGET
#
#   plaace_hierarchy_id     sales_channel_name  grunnkrets_id  \
# 0             1.1.1.0  Hamburger restaurants        6020303
# 1             1.1.1.0  Hamburger restaurants        3010306
# 2             1.1.1.0  Hamburger restaurants        6050102
# 3             1.1.1.0  Hamburger restaurants       18040102
# 4             1.1.1.0  Hamburger restaurants       16017414
#
#              address        lat        lon   chain_name          mall_name  \
# 0  BRAGERNES TORG 13  59.743104  10.204928    MCDONALDS  Magasinet Drammen
# 1                NaN  59.913759  10.734031    MCDONALDS                NaN
# 2  KONG RINGS GATE 1  60.164751  10.254656  BURGER KING     Kuben Hønefoss
# 3        STORGATA 12  67.283669  14.379796  BURGER KING  Glasshuspassasjen
# 4                NaN  63.358068  10.374832  BURGER KING       Tillertorget
#
#    revenue  year_y  all_households   singles  couple_without_children  \
# 0   17.998  2016.0        398700.0  277500.0                 669100.0
# 1   23.828  2016.0        374800.0  295000.0                 679600.0
# 2   16.099  2016.0        347900.0  251900.0                 589900.0
# 3    9.296  2016.0        394000.0  293600.0                 602000.0
# 4    4.528  2016.0        623700.0  296500.0                 635700.0
#
#    couple_with_children  other_households  single_parent_with_children
# 0              832800.0          679600.0                     349500.0
# 1              802200.0          604100.0                     397700.0
# 2              673100.0          637600.0                     327000.0
# 3              675800.0          699600.0                     335200.0
# 4              779700.0          801300.0                     413600.0

# %%
stores_train.head()
# Out:
#                      store_id  year                           store_name  \
# 0   983540538-974187930-44774  2016  MCDONALD'S BRAGERNES TORG MAGASINET
# 1   987074191-973117734-44755  2016           MCDONALD'S KLINGENBERGGATA
# 2   984890265-981157303-64491  2016                 BURGER KING HØNEFOSS
# 3  914057442-992924179-126912  2016        BURGER KING GLASSHUSPASSASJEN
# 4  913018583-913063538-668469  2016             BURGER KING TILLERTORGET
#
#   plaace_hierarchy_id     sales_channel_name  grunnkrets_id  \
# 0             1.1.1.0  Hamburger restaurants        6020303
# 1             1.1.1.0  Hamburger restaurants        3010306
# 2             1.1.1.0  Hamburger restaurants        6050102
# 3             1.1.1.0  Hamburger restaurants       18040102
# 4             1.1.1.0  Hamburger restaurants       16017414
#
#              address        lat        lon   chain_name          mall_name  \
# 0  BRAGERNES TORG 13  59.743104  10.204928    MCDONALDS  Magasinet Drammen
# 1                NaN  59.913759  10.734031    MCDONALDS                NaN
# 2  KONG RINGS GATE 1  60.164751  10.254656  BURGER KING     Kuben Hønefoss
# 3        STORGATA 12  67.283669  14.379796  BURGER KING  Glasshuspassasjen
# 4                NaN  63.358068  10.374832  BURGER KING       Tillertorget
#
#    revenue
# 0   17.998
# 1   23.828
# 2   16.099
# 3    9.296
# 4    4.528

# %%
def average_income_per_grunnkrets():
    avg_income_per_household = []
    parameters = ["singles", "couple_without_children", "couple_with_children", "other_households", "single_parent_with_children"]

    for index, row in stores_with_households_income.iterrows():
        mean_income = 0
        average_divide = 0
        for param in parameters:
            if (row[param] > 0):
                mean_income += row[param]
                average_divide += 1
        if (average_divide > 0):
            mean_income = mean_income / average_divide
        else: 
            mean_income = 0
        avg_income_per_household.append(mean_income)
                
    return avg_income_per_household


instance = average_income_per_grunnkrets()
avg_income = pd.DataFrame()
avg_income["average_income_per_grunnkrets"] = np.asarray(instance)
avg_income.to_csv("../features_train_csv/average_income_per_grunnkrets.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /Users/ashildfridtun/OneDrive-NTNU/4klasse/machinelearning/project_ml/project_ml/features_code/feature_grunnkrets_income.ipynb Cell 11 in <cell line: 24>()
#      <a href='vscode-notebook-cell:/Users/ashildfridtun/OneDrive-NTNU/4klasse/machinelearning/project_ml/project_ml/features_code/feature_grunnkrets_income.ipynb#X12sZmlsZQ%3D%3D?line=21'>22</a> avg_income = pd.DataFrame()
#      <a href='vscode-notebook-cell:/Users/ashildfridtun/OneDrive-NTNU/4klasse/machinelearning/project_ml/project_ml/features_code/feature_grunnkrets_income.ipynb#X12sZmlsZQ%3D%3D?line=22'>23</a> avg_income["average_income_per_grunnkrets"] = np.asarray(instance)
# ---> <a href='vscode-notebook-cell:/Users/ashildfridtun/OneDrive-NTNU/4klasse/machinelearning/project_ml/project_ml/features_code/feature_grunnkrets_income.ipynb#X12sZmlsZQ%3D%3D?line=23'>24</a> avg_income.to_csv("../features_csv/average_income_per_grunnkrets.csv", index=False)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/generic.py:3466, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3455 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3457 formatter = DataFrameFormatter(
#    3458     frame=df,
#    3459     header=header,
#    (...)
#    3463     decimal=decimal,
#    3464 )
# -> 3466 return DataFrameRenderer(formatter).to_csv(
#    3467     path_or_buf,
#    3468     line_terminator=line_terminator,
#    3469     sep=sep,
#    3470     encoding=encoding,
#    3471     errors=errors,
#    3472     compression=compression,
#    3473     quoting=quoting,
#    3474     columns=columns,
#    3475     index_label=index_label,
#    3476     mode=mode,
#    3477     chunksize=chunksize,
#    3478     quotechar=quotechar,
#    3479     date_format=date_format,
#    3480     doublequote=doublequote,
#    3481     escapechar=escapechar,
#    3482     storage_options=storage_options,
#    3483 )
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/io/formats/format.py:1105, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1084     created_buffer = False
#    1086 csv_formatter = CSVFormatter(
#    1087     path_or_buf=path_or_buf,
#    1088     line_terminator=line_terminator,
#    (...)
#    1103     formatter=self.fmt,
#    1104 )
# -> 1105 csv_formatter.save()
#    1107 if created_buffer:
#    1108     assert isinstance(path_or_buf, StringIO)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/io/formats/csvs.py:237, in CSVFormatter.save(self)
#     233 """
#     234 Create the writer & save.
#     235 """
#     236 # apply compression and byte/text conversion
# --> 237 with get_handle(
#     238     self.filepath_or_buffer,
#     239     self.mode,
#     240     encoding=self.encoding,
#     241     errors=self.errors,
#     242     compression=self.compression,
#     243     storage_options=self.storage_options,
#     244 ) as handles:
#     245
#     246     # Note: self.encoding is irrelevant here
#     247     self.writer = csvlib.writer(
#     248         handles.handle,  # type: ignore[arg-type]
#     249         lineterminator=self.line_terminator,
#    (...)
#     254         quotechar=self.quotechar,
#     255     )
#     257     self._save()
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/io/common.py:702, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     697 elif isinstance(handle, str):
#     698     # Check whether the filename is to be opened in binary mode.
#     699     # Binary mode does not support 'encoding' and 'newline'.
#     700     if ioargs.encoding and "b" not in ioargs.mode:
#     701         # Encoding
# --> 702         handle = open(
#     703             handle,
#     704             ioargs.mode,
#     705             encoding=ioargs.encoding,
#     706             errors=errors,
#     707             newline="",
#     708         )
#     709     else:
#     710         # Binary mode
#     711         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../features_csv/average_income_per_grunnkrets.csv'
